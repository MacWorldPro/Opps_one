# %% [markdown]
# #Question 1
# A class is code template for creating objects,we can say it is systematic way to store and access the code.For eg in real world we say car which can be compared to class. Object can be called an instance of class for eg in class of car specific name of a car can be called it's object.

# %% [markdown]
# #Question 2
# The four pillars of OOPs are:
# Inheritance, Polymorphism, Encapsulation and Abstraction.

# %% [markdown]
# #Question 3
# __init__() function is used to take values from values in class and assign values to the defined class varibales. for eg
# class car:
#   def __init__(self,name,number,color):
#     self.name1=name
#     self.number1=number
#     self.color1=color
# By using these varibales we can assign to any function of class and use it outside the class for accessing it's values.

# %% [markdown]
# #Question 4
# self is a pointer that is used to point the variables to the class to ensure the class that this varibales or function belong to class itself.

# %% [markdown]
# #Question 5
# Inheritance is a class that is depedent to other class.Eg
# class Father:
#   def __init__(self,name,bloodgrp):
#     self.name1=name
#     self.bloodgrp1=bloodgrp
# class Son(Father):
#   pass
# Alll the varibales of Father can be accessed by Son as it is in upper hericharchy.
